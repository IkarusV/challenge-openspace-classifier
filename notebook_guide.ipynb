# %% [markdown]
# # Open Space Organizer
#
# We want to create a program that assigns 24 people to 6 tables in an openspace. Before getting started, take inventory what do we need:
#
# - People
# - Seats & Tables
# - An OpenSpace
#
# It's a good practice to start simple while you grasp the logic of the program you are trying to build and test often. For us this can translate to,
#
# - People -> List of Names (later we can figure out how to use a file)
# - Seats & Tables -> Class
# - An OpenSpace -> Class
#
# Below I've created a list of your new colleagues for reference!

# %%
new_collegues = names = ["Anna", "Dan", "Gaetan", "Guillermo", "Gunay", 
                         "Hiba", "Hussein", "Ibrahim", "Ibtihel", "Imad", "Iness", 
                         "Irene","Jeong", "Mahalakshmi", "Max", "Neha", "Siegried", 
                         "Sitara", "Sooyoung", "Stephane", "Thi", "Uzair", "Victor", "Vanessa"]

# %% [markdown]
# ## Step 1: Build a Seat
#
# Create a class called `Seat` with two attributes:
#
# - `free` which is a boolean.
# - `occupant` which is a string.
#
# and 2 methods (functions):
#
# - `set_occupant(name)` which allows the program to assign someone a seat if it's free
# - `remove_occupant()` which  remove someone from a seat and return the name of the person occupying the seat before

# %%
# Your code here
class Seat:
    def __init__(self, free, occupant):
        self.free = free
        self.occupant = occupant
    def set_occupant(self, occupant):
        self.occupant = occupant
        self.free = False
        if self.free == False:
            print(f"{self.occupant} is now occupying the seat.")
    def remove_occupant(self):
        self.free = True 
        if self.free == True:
            print(f"The seat is now free of {self.occupant}.")
            self.occupant = None
    def __str__(self):
        return f"Seat: {'Free' if self.free else f'Occupied by {self.occupant}'}"

# %%
# Test your code (assign yourself you a Seat)
seat1 = Seat(True, "Imad")
print(seat1)
seat1.set_occupant("Imad")
print(seat1)
seat1.remove_occupant()
print(seat1)
# Out:
# Seat: Free
# Imad is now occupying the seat.
# Seat: Occupied by Imad
# The seat is now free of Imad.
# Seat: Free

# %% [markdown]
# What is the input and the output of your Seat class? Does it make sense?
#
# ## Step 2: Build a Table
#
# Create a class `Table` with ? attributes:
#
# - `capacity` which is an integer
# - `seats` which is a list of `Seat` objects (size = `capacity`)
#
# and 3 methods (functions):
# - `has_free_spot()` that returns a boolean (True if a spot is available)
# - `assign_seat(name)` that places someone at the table
# - `left_capacity()` that returns an integer
#
# Question: Which attributes make sense to give? For now let's say we want to build 6 tables with 4 seats.

# %%
# Your code here
class Table:
    def __init__(self, capacity, seats):
        self.capacity = int(capacity)
        self.seats = seats
    def has_free_spot(self, seats):
        for seat in self.seats:#do a for loop to check each seats with a if statement to check if they are true.
            if seat.free:
                return True
        return False
    def assign_seat(self, seats, name="New Occupant"):
        if self.has_free_spot(seats):
            for seat in self.seats:
                if seat.free:#if the seat is free, then we can asign the name to the seat with a default in case.
                    seat.set_occupant(name)
                    break
        else:
            print("No free spots available at the table.")
    def left_capacity(self):#calculate using not seat.free so the opposite of free,looking for false table to have the count then reduce the capacity with the count of occupied false seats.
        occupied_seats = sum(not seat.free for seat in self.seats)
        return self.capacity - occupied_seats

# %%
# Test your code (assign the colleagues at your table to a Table)
table1 = Table(4, [Seat(True, None) for _ in range(4)])
print(table1.has_free_spot(table1.seats))
table1.assign_seat(table1.seats, "Ibrahim")
print(table1.left_capacity())
table1.assign_seat(table1.seats, "Imad")
table1.assign_seat(table1.seats, "Sooyoung")
print(table1.left_capacity())
table1.assign_seat(table1.seats, "Ibhitel")
print(table1.left_capacity())
table1.assign_seat(table1.seats, "intruder")
print(table1.left_capacity())
# Out:
# True
# Ibrahim is now occupying the seat.
# 3
# Imad is now occupying the seat.
# Sooyoung is now occupying the seat.
# 1
# Ibhitel is now occupying the seat.
# 0
# No free spots available at the table.
# 0

# %% [markdown]
# Does the output of you test make sense? Check that each method returns the correct value.

# %% [markdown]
# ## Step 3: Build an OpenSpace
#
# Create a class `Openspace` that contains these attributes:
#
# - `tables` which is a list of `Table`.
# - `number_of_tables` which is an integer.
#
# And some methods:
#
# - `organize(names)` that will:
#   - **randomly** assign people to `Seat` objects in the different `Table` objects. (hint: explore the `random` library )
# - `display()` display the different tables and there occupants in a nice and readable way
# - `store(filename)` store the repartition in an file

# %%
# Your code here
import random
class Openspace:
    def __init__(self, tables, number_of_tables):
        self.tables = tables
        self.number_of_tables = number_of_tables
    def organize(self, names):
        random.shuffle(names)
        for name in names:
            assigned = False
            for table in self.tables:
                if table.has_free_spot(table.seats):
                    table.assign_seat(table.seats, name)
                    assigned = True
                    break
            if not assigned:
                print(f"No free spots available for {name}.")
    def display(self):
        for people, table in enumerate(self.tables):
            print(f"Table {people + 1}:")
            for seat in table.seats:
                print(f"  - {seat}")
    def store(self, filename):
        with open(filename, 'w') as f:
            for people, table in enumerate(self.tables):
                f.write(f"Table {people + 1}:\n")
                for seat in table.seats:
                    f.write(f"  - {seat}\n")

# %%
# Test your code (assign everyone in the class to a table)
openspace1 = Openspace([Table(4, [Seat(True, None) for _ in range(4)]) for _ in range(6)], 6)
openspace1.organize(new_collegues)
openspace1.display()
openspace1.store("output.csv")
# Out:
# Uzair is now occupying the seat.
# Gaetan is now occupying the seat.
# Hussein is now occupying the seat.
# Gunay is now occupying the seat.
# Thi is now occupying the seat.
# Sooyoung is now occupying the seat.
# Irene is now occupying the seat.
# Siegried is now occupying the seat.
# Iness is now occupying the seat.
# Vanessa is now occupying the seat.
# Imad is now occupying the seat.
# Sitara is now occupying the seat.
# Victor is now occupying the seat.
# Jeong is now occupying the seat.
# Stephane is now occupying the seat.
# Hiba is now occupying the seat.
# Neha is now occupying the seat.
# Guillermo is now occupying the seat.
# Ibtihel is now occupying the seat.
# Ibrahim is now occupying the seat.
# Dan is now occupying the seat.
# Mahalakshmi is now occupying the seat.
# Max is now occupying the seat.
# Anna is now occupying the seat.
# Table 1:
#   - Seat: Occupied by Uzair
#   - Seat: Occupied by Gaetan
#   - Seat: Occupied by Hussein
#   - Seat: Occupied by Gunay
# Table 2:
#   - Seat: Occupied by Thi
#   - Seat: Occupied by Sooyoung
#   - Seat: Occupied by Irene
#   - Seat: Occupied by Siegried
# Table 3:
#   - Seat: Occupied by Iness
#   - Seat: Occupied by Vanessa
#   - Seat: Occupied by Imad
#   - Seat: Occupied by Sitara
# Table 4:
#   - Seat: Occupied by Victor
#   - Seat: Occupied by Jeong
#   - Seat: Occupied by Stephane
#   - Seat: Occupied by Hiba
# Table 5:
#   - Seat: Occupied by Neha
#   - Seat: Occupied by Guillermo
#   - Seat: Occupied by Ibtihel
#   - Seat: Occupied by Ibrahim
# Table 6:
#   - Seat: Occupied by Dan
#   - Seat: Occupied by Mahalakshmi
#   - Seat: Occupied by Max
#   - Seat: Occupied by Anna

# %% [markdown]
# Hurray! You have the algorithm logic working. Next steps we transform this into some scripts! **Big note:** Once you move to the scrips you may need to adapt your logic.
